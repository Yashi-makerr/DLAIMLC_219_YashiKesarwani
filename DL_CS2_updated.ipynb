# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = models.Sequential()

model.add(layers.Input(shape=(32, 32, 3)))

# %%
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same'))

# %%
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(32, (3,3), activation='relu'))

model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Dropout(0.25))

# %%
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, (3,3), activation='relu'))

model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Dropout(0.25))

# %%
model.add(layers.Flatten())

# %%
model.add(layers.Dense(128, activation='relu'))

# %%
model.add(layers.Dropout(0.5))

model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    x_train,
    y_train,
    epochs=10,
    validation_data=(x_test, y_test)
)
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 144s 92ms/step - accuracy: 0.5333 - loss: 1.3054 - val_accuracy: 0.5828 - val_loss: 1.2327
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 144s 92ms/step - accuracy: 0.5954 - loss: 1.1546 - val_accuracy: 0.6918 - val_loss: 0.8986
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 202s 93ms/step - accuracy: 0.6416 - loss: 1.0319 - val_accuracy: 0.6891 - val_loss: 0.8889
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 202s 93ms/step - accuracy: 0.6665 - loss: 0.9668 - val_accuracy: 0.6685 - val_loss: 1.0013
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 146s 93ms/step - accuracy: 0.6901 - loss: 0.9051 - val_accuracy: 0.7304 - val_loss: 0.7830
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 149s 95ms/step - accuracy: 0.7063 - loss: 0.8564 - val_accuracy: 0.7290 - val_loss: 0.7844
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 198s 93ms/step - accuracy: 0.7178 - loss: 0.8224 - val_accuracy: 0.7536 - val_loss: 0.7254
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 200s 92ms/step - accuracy: 0.7312 - loss: 0.7832 - val_accuracy: 0.7557 - val_loss: 0.7036
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 148s 94ms/step - accuracy: 0.7374 - loss: 0.7608 - val_accuracy: 0.7637 - val_loss: 0.7042
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 148s 95ms/step - accuracy: 0.7435 - loss: 0.7420 - val_accuracy: 0.7596 - val_loss: 0.7218
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.7596 - loss: 0.7218
# Test accuracy: 0.7595999836921692
